# %% [markdown]
# <a href="https://colab.research.google.com/github/Leejungs/2024-1-my-BDA/blob/main/04w_0401_mon_ch06_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##파이썬 설치 확인

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns

print(sys.version)
print(np.__version__)
print(pd.__version__)
print(sns.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.25.2
# 1.5.3
# 0.13.1

# %% [markdown]
# ##수업에서 사용할 데이터를 깃에서 복사

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 4.00 MiB | 6.03 MiB/s, done.

# %% [markdown]
# ##코랩에서 한글 처리

# %%
# !pip install koreanize_matplotlib

# %%
# 데이터프레임의 소수점 이하 n자리 출력 설정
pd.set_option('display.precision', 2)

import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-1, 0 , 1 ,2])
plt.title('그래프 제목')
plt.xlabel('간단한 그래프')
plt.show()

# %%
s = pd.Series(['a','b','c','d'], index=[3,2,1,4])
s.sort_index()
# Out:
# 1    c
# 2    b
# 3    a
# 4    d
# dtype: object

# %%
s.sort_index()
# Out:
# 1    c
# 2    b
# 3    a
# 4    d
# dtype: object

# %%
s.sort_values()
# Out:
# 3    a
# 2    b
# 1    c
# 4    d
# dtype: object

# %%
df = pd.DataFrame([1, 2 ,3, 4],index = [100, 29, 234.1 ,150],
                  columns = ['A'])
df
# Out:
#        A
# 100.0  1
# 29.0   2
# 234.1  3
# 150.0  4

# %%
import pandas as pd

exam = pd.read_csv('data/exam.csv')
exam.sample(frac=.2)
# Out:
#     id  nclass  math  english  science
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 3    4       1    30       98       58
# 8    9       3    20       98       15

# %%
# exam에서 nclass가 1인 경우만 추출
exam.query('nclass == 1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
# 1, 3, 5반에 해당하면 추출
exam.query('nclass == 2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
#1번이 아닌경우
exam.query('nclass != 1')
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass==2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
#1번이 아닌경우
exam.query('nclass != 1')
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass != 2')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[(exam['nclass']==2)]
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam[exam.nclass!=3]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam.nclass==2]
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam[exam.nclass==3]
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %% [markdown]
# ##초과,미만,이상,이하 조건 걸기

# %%
#수학 점수가 50점을 초과한 경우
exam.query('math>50')
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
#영어 점수가 50점 이상인 경우
exam.query('english>=50')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
#수학 점수가 50점 미만인 경우
exam.query('math<50')
# Out:
#     id  nclass  math  english  science
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12

# %%
#영어 점수가 80점 이하인 경우
exam.query('english<=80')
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %% [markdown]
# ##여러 조건을 충족하는 행 추출하기

# %%
#1이면서 수학점수가 50점 이상인 경우
exam.query('nclass==1 & math>=50')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam[(exam.nclass==1) & (exam.math>=50)]  #괄호를 반드시 사용
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %% [markdown]
# ##여러 조건중 하나 이상 충족하는 행 추출하기

# %%
#영어 점수가 90점 미만인거나 과학 점수가 50점 미만인 경우\
exam.query('english<80 | science<50')
# Out:
#     id  nclass  math  english  science
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %%
#수학 점수가 90점 이상이거나 영어 점수가 90점 이상인 경우
exam.query('math>=90 | english>=90')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 12  13       4    46       98       65
# 15  16       4    58       98       65

# %%
3 in [1,2,3,4]
# Out:
# True

# %%
#1,3,5번에 해당하면 추출
exam.query('nclass in [1,3,5]') #시험 예상
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam.nclass.isin([1,3,5])]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam['nclass'].isin([1,3,5])]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam.nclass.isin([1, 3, 5])]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ## 추출한 행으로 데이터 만들기

# %%
# nclass가 1인 행 추출해 nclass1에 할당
nclass1 = exam.query('nclass == 1')

# nclass가 2인 행 추출해 nclass2에 할당
nclass2 = exam.query('nclass == 2')

# %%
nclass1['math'].mean()  # 1반 수학 점수 평균 구하기

# %%
nclass2['math'].mean()  # 2반 수학 점수 평균 구하기

# %%
# nclass가 1인 행 추출해 nclass1에 할당
nclass1 = exam[exam.nclass == 1]

# nclass가 2인 행 추출해 nclass2에 할당
nclass2 = exam[exam.nclass == 2]

# %%
nclass1['math'].mean()  # 1반 수학 점수 평균 구하기

# %%
nclass1.math.mean()  # 1반 수학 점수 평균 구하기

# %%
nclass2.math.mean()  # 2반 수학 점수 평균 구하기

# %% [markdown]
# ## 문자 변수를 이용해 조건에 맞는 행 추출하기

# %%
df = pd.DataFrame({'sex'     : ['F', 'M', 'F', 'M'],
                   'country' : ['Korea', 'China', 'Japan', 'USA']})
df

# %%
# 전체 조건에 작은따옴표, 추출할 문자에 큰따옴표 사용
df.query('sex == "F" & country == "Korea"')

# %%
# 전체 조건과 추출할 문자에 모두 작은따옴표 사용
df.query("sex == 'F' & country == 'Korea'")

# %%
# 전체 조건에 큰따옴표, 추출할 문자에 작은따옴표 사용
df.query("sex == 'M' & country == 'China'")

# %% [markdown]
# ## 메소드 df.isin()

# %%
df = pd.DataFrame({'num_legs': [2,4], 'num_wings': [2,0]},
                  index=['falcon', 'dog'])
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0

# %%
df.isin([0.4]) #list나 dict 형태
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog        False      False

# %%
~df.isin([0, 4])
# Out:
#         num_legs  num_wings
# falcon      True       True
# dog        False      False

# %% [markdown]
# ## 06-3 필요한 변수만 추출하기

# %%
exam["math"] #시리즈
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam.math
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam[['math','english']]
#두 과목을 한꺼번에 dataframe으로 출력
# Out:
#     math  english
# 0     50       98
# 1     60       97
# 2     45       86
# 3     30       98
# 4     25       80
# 5     50       89
# 6     80       90
# 7     90       78
# 8     20       98
# 9     50       98
# 10    65       65
# 11    45       85
# 12    46       98
# 13    48       87
# 14    75       56
# 15    58       98
# 16    65       68
# 17    80       78
# 18    89       68
# 19    78       83

# %%
exam.columns
# Out:
# Index(['id', 'nclass', 'math', 'english', 'science'], dtype='object')

# %%
exam.columns[3]
# Out:
# 'english'

# %%
exam[exam.columns[3]]
#exam["english"]와 동일
# Out:
# 0     98
# 1     97
# 2     86
# 3     98
# 4     80
# 5     89
# 6     90
# 7     78
# 8     98
# 9     98
# 10    65
# 11    85
# 12    98
# 13    87
# 14    56
# 15    98
# 16    68
# 17    78
# 18    68
# 19    83
# Name: english, dtype: int64

# %%
exam.columns[1:3]
# Out:
# Index(['nclass', 'math'], dtype='object')

# %%
exam[exam.columns[1:3]]
# Out:
#     nclass  math
# 0        1    50
# 1        1    60
# 2        1    45
# 3        1    30
# 4        2    25
# 5        2    50
# 6        2    80
# 7        2    90
# 8        3    20
# 9        3    50
# 10       3    65
# 11       3    45
# 12       4    46
# 13       4    48
# 14       4    75
# 15       4    58
# 16       5    65
# 17       5    80
# 18       5    89
# 19       5    78

# %% [markdown]
# ## 변수 제거하기

# %%
ㄷㅇexam.drop(columns="math")
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam.head(3)
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78

# %%
exam.drop(columns=["math", "english"])
# columns라고 써야 열이 삭제가 됨
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(2)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop([2, 4, 6])
#리스트 []를 사용해 2, 4, 6을 쓰면 3개 모두 삭제가능.
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index=[2, 4, 6])
#index를 사용하지않아도됨
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=[2, 4, 6], axis=0)
#행이 삭제가 됨 2,4,6은 labels
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=["math", "english"], axis=1)
#axis를 0이아닌 다른 숫자일 때는 labels를 2,4,6과 같은 숫자가 아니라 문자를 써야 됨.
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %% [markdown]
# ##pandas 함수 조합하기

# %%
exam.query('nclass == 1')[['math', 'english']]
# Out:
#    math  english
# 0    50       98
# 1    60       97
# 2    45       86
# 3    30       98

# %%
exam.query('nclass == 1')[['math', 'english']]
#math만 나오게 , 시리즈가아니라 DataFrame을 보고싶을 때("리스트"로)
# Out:
#    math  english
# 0    50       98
# 1    60       97
# 2    45       86
# 3    30       98

# %%
#math가 50 이상인 행만 추출한 다음, 열 id, math 추출 #시험문제
exam.query('math >= 50')[['id', 'math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam[exam.math >= 50][['id', 'math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam[exam.math >= 50][['id', 'math']].head(3)
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50

# %% [markdown]
# ###가독성 있게 코드 줄 바꾸기

# %%
#math가 50 이상인 행만 추출
# id, math 추출
# 앞부분 10행 추출
exam.query('math >= 50') \
    [['id', 'math']] \
    .head(10)
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65

# %%
exam.query('math >= 50')[['id', 'math']].head(10)
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65

# %% [markdown]
# ##06-4 순서대로 정렬하기

# %%
exam.sort_values('math', ascending=False).head(4)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 6    7       2    80       90       45

# %%
#nclass, math 오름차순 정렬
exam.sort_values(['nclass', 'math']).head(10)
# Out:
#     id  nclass  math  english  science
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 11  12       3    45       85       32

# %%
#nclass 오름차순 정렬, math 내림차순 정렬
#ascending을 True면 오름차순 False면 내림차순
exam.sort_values(['nclass', 'math'], ascending=[True, False]).head(10)
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45

# %% [markdown]
# ##df.sort_index()

# %%
exam.sort_index(ascending=False).head()
# Out:
#     id  nclass  math  english  science
# 19  20       5    78       83       58
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 16  17       5    65       68       98
# 15  16       4    58       98       65

# %% [markdown]
# ##06-5 파생변수 추가하기

# %%
# total 변수 추가
exam.assign(total = exam['math'] + exam['english'] + exam['science'])
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
# total 변수 추가
exam['total'] = exam['math'] + exam['english'] + exam['science']
exam # total이 반영됨.
#새로운 열 추가 => assign
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
exam.head()
# Out:
#    id  nclass  math  english  science  total
# 0   1       1    50       98       50    198
# 1   2       1    60       97       60    217
# 2   3       1    45       86       78    209
# 3   4       1    30       98       58    186
# 4   5       2    25       80       65    170

# %% [markdown]
# ##여러 파생변수 한 번에 추가하기

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'],          # total 추가
            mean = (exam['math'] + exam['english'] + exam['science']) / 3)     # mean 추가
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %% [markdown]
# ##df.assign()에 np.where() 적용하기

# %%
import numpy as np
exam.assign(test = np.where(exam['science'] >= 60, 'pass', 'fail'))
# Out:
#     id  nclass  math  english  science  total  test
# 0    1       1    50       98       50    198  fail
# 1    2       1    60       97       60    217  pass
# 2    3       1    45       86       78    209  pass
# 3    4       1    30       98       58    186  fail
# 4    5       2    25       80       65    170  pass
# 5    6       2    50       89       98    237  pass
# 6    7       2    80       90       45    215  fail
# 7    8       2    90       78       25    193  fail
# 8    9       3    20       98       15    133  fail
# 9   10       3    50       98       45    193  fail
# 10  11       3    65       65       65    195  pass
# 11  12       3    45       85       32    162  fail
# 12  13       4    46       98       65    209  pass
# 13  14       4    48       87       12    147  fail
# 14  15       4    75       56       78    209  pass
# 15  16       4    58       98       65    221  pass
# 16  17       5    65       68       98    231  pass
# ...

# %% [markdown]
# ##추가한 변수를 pandas 코드에 바로 활용하기

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science']).sort_values('total')
#total
# Out:
#     id  nclass  math  english  science  total
# 8    9       3    20       98       15    133
# 13  14       4    48       87       12    147
# 11  12       3    45       85       32    162
# 4    5       2    25       80       65    170
# 3    4       1    30       98       58    186
# 9   10       3    50       98       45    193
# 7    8       2    90       78       25    193
# 10  11       3    65       65       65    195
# 0    1       1    50       98       50    198
# 2    3       1    45       86       78    209
# 12  13       4    46       98       65    209
# 14  15       4    75       56       78    209
# 6    7       2    80       90       45    215
# 1    2       1    60       97       60    217
# 19  20       5    78       83       58    219
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 5    6       2    50       89       98    237
# 18  19       5    89       68       87    244
# ...

# %%
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %% [markdown]
# ##lambda 함수를 이용해 데이터 프레임명 줄여 쓰기

# %%
# long_name 대신 x 입력
exam.assign(new = lambda x: x['math'] + x['english'] + x['science'])
# Out:
#     id  nclass  math  english  science  new
# 0    1       1    50       98       50  198
# 1    2       1    60       97       60  217
# 2    3       1    45       86       78  209
# 3    4       1    30       98       58  186
# 4    5       2    25       80       65  170
# 5    6       2    50       89       98  237
# 6    7       2    80       90       45  215
# 7    8       2    90       78       25  193
# 8    9       3    20       98       15  133
# 9   10       3    50       98       45  193
# 10  11       3    65       65       65  195
# 11  12       3    45       85       32  162
# 12  13       4    46       98       65  209
# 13  14       4    48       87       12  147
# 14  15       4    75       56       78  209
# 15  16       4    58       98       65  221
# 16  17       5    65       68       98  231
# 17  18       5    80       78       90  248
# 18  19       5    89       68       87  244
# 19  20       5    78       83       58  219

# %%
(lambda x, y: x + y)(30, 40)
# Out:
# 70

# %%
f = lambda x, y: x + y
f(30,40)
# Out:
# 70

# %%
import pandas as pd

exam = pd.read_csv('data/exam.csv')

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'],
            mean = lambda x: round(x['total'] / 3))
# Out:
#     id  nclass  math  english  science  total  mean
# 0    1       1    50       98       50    198  66.0
# 1    2       1    60       97       60    217  72.0
# 2    3       1    45       86       78    209  70.0
# 3    4       1    30       98       58    186  62.0
# 4    5       2    25       80       65    170  57.0
# 5    6       2    50       89       98    237  79.0
# 6    7       2    80       90       45    215  72.0
# 7    8       2    90       78       25    193  64.0
# 8    9       3    20       98       15    133  44.0
# 9   10       3    50       98       45    193  64.0
# 10  11       3    65       65       65    195  65.0
# 11  12       3    45       85       32    162  54.0
# 12  13       4    46       98       65    209  70.0
# 13  14       4    48       87       12    147  49.0
# 14  15       4    75       56       78    209  70.0
# 15  16       4    58       98       65    221  74.0
# 16  17       5    65       68       98    231  77.0
# ...

# %%
round(3.4567876, 2)
#소수점 둘째 자리 까지보여줌
# Out:
# 3.46

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'],
            mean = lambda x: round(x['total'] / 3, 2))
# Out:
#     id  nclass  math  english  science  total   mean
# 0    1       1    50       98       50    198  66.00
# 1    2       1    60       97       60    217  72.33
# 2    3       1    45       86       78    209  69.67
# 3    4       1    30       98       58    186  62.00
# 4    5       2    25       80       65    170  56.67
# 5    6       2    50       89       98    237  79.00
# 6    7       2    80       90       45    215  71.67
# 7    8       2    90       78       25    193  64.33
# 8    9       3    20       98       15    133  44.33
# 9   10       3    50       98       45    193  64.33
# 10  11       3    65       65       65    195  65.00
# 11  12       3    45       85       32    162  54.00
# 12  13       4    46       98       65    209  69.67
# 13  14       4    48       87       12    147  49.00
# 14  15       4    75       56       78    209  69.67
# 15  16       4    58       98       65    221  73.67
# 16  17       5    65       68       98    231  77.00
# ...

# %%
# 데이터프레임의 소수점 이하 n자리 출력 설정
import pandas as pd
pd.set_option('display.precision', 2)

# %% [markdown]
# ##정리하기

# %%
## 1. 조건에 맞는 데이터만 추출하기
exam.query('english <= 80')

# 여러 조건 동시 충족
exam.query('nclass == 1 & math >= 50')
# 여러 조건 중 하나 이상 충족
exam.query('math >= 90 | english >= 90')
exam.query('nclass in [1, 3, 5]')

##2. 필요한 변수만 추출하기
exam['math']                             #한 변수 추출
exam[['nclass', 'math', 'english']]      #여러 변수 추출
exam.drop(columns = 'math')              #변수 제거
exam.drop(columns = ['math', 'english']) #여러 변수 제거

## 3. pandas 명령어 조합하기
exam.query('math >= 50')[['id', 'math']].head()

## 4. 순서대로 정렬하기
exam.sort_values('math') #오름차순 정렬
exam.sort_values('math', ascending = False) #내림차순 정렬

# 여러 변수 기준 정렬
exam.sort_values(['nclass', 'math'], ascending = [True, False])

## 5. 파생변수 추가하기
exam.assign(total = exam['math'] + exam['english'] + exam['science'])

# 여러 파생변수 한 번에 추가하기
exam.assign(total = exam['math'] + exam['english'] + exam['science'],
            mean = (exam['math'] + exam['english'] + exam['science']) / 3)

# assign()에 np.where() 적용하기
exam.assign(test = np.where(exam['science'] >= 60, 'pass', 'fail'))

# 추가한 변수를 pandas 코드에 바로 활용하기
exam.assign(total = exam['math'] + exam['english'] + exam['science']) \
            .sort_values(total) \
            .head()
