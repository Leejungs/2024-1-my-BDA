# %% [markdown]
# <a href="https://colab.research.google.com/github/Leejungs/2024-1-my-BDA/blob/main/03w_0325_mon_ch05_dataframe_edium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #파이썬 설치 확인

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import sys
import pandas as pd
import numpy as np

print(sys.version)
print(np.__version__)
print(pd.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.25.2
# 1.5.3

# %% [markdown]
# #코랩에서 한글 처리

# %%
# !pip install koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 15.6 MB/s eta 0:00:00
# ...

# %%
#해상도 선명하게
# %config inlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-1, 0 , 1 ,2])
plt.title('그래프 제목')
plt.xlabel('간단한 그래프')
plt.show()

# %% [markdown]
# #데이터 분석 기초! = 데이터파악하기,다루기쉽게 수정하기

# %% [markdown]
# 함수 | 기능 |
# |----|------|
# |head()앞부분 출력

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 4.00 MiB | 5.65 MiB/s, done.

# %%
import pandas as pd
exam = pd.read_csv("data/exam.csv")

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
exam.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.shape
# Out:
# (20, 5)

# %%
exam.describe()
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# #mpg 데이터 파악하기

# %%
import pandas as pd
# mpg 데이터 불러오기
mpg = pd.read_csv('data/mpg.csv')

# %%
mpg.head(8) #윗부분의 8개 정보를 보여줌
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4         audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5         audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6         audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 7         audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
#
#   category
# 0  compact
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact
# 6  compact
# 7  compact

# %%
mpg.tail() #마지막부분의 정보 보여준다.
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.sample(10) #sample은 랜덤으로 정보를 알려줌
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 92          ford       mustang    4.0  2008    6  manual(m5)   r   17   26  r
# 121      hyundai       tiburon    2.7  2008    6  manual(m5)   f   17   24  r
# 10          audi    a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# 26     chevrolet      corvette    6.2  2008    8    auto(s6)   r   15   25  p
# 165       subaru   impreza awd    2.2  1999    4    auto(l4)   4   21   26  r
# 189       toyota  camry solara    2.4  2008    4    auto(s5)   f   22   31  r
# 208   volkswagen           gti    2.0  1999    4    auto(l4)   f   19   26  r
# 210   volkswagen           gti    2.0  2008    4    auto(s6)   f   22   29  p
# 207   volkswagen           gti    2.0  1999    4  manual(m5)   f   21   29  r
# 228   volkswagen        passat    1.8  1999    4    auto(l5)   f   18   29  p
#
#        category
# 92   subcompact
# 121  subcompact
# 10      compact
# 26      2seater
# 165  subcompact
# ...

# %%
mpg.info()
#범주형 데이터 : 나뉠수있다 명목형과 순서형
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe(include="all") #수치
#category가 다른걸 확인할수있음.
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %%
mpg[["category"]] #카테고리만 나오게함
# Out:
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 1 columns]

# %%
mpg[["category"]].describe() #범주형데이터 열만 가지고하면 이렇게나옴
# Out:
#        category
# count       234
# unique        7
# top         suv
# freq         62

# %%
mpg[["manufacturer","model","trans","drv","fl","category"]].describe()
# Out:
#        manufacturer        model     trans  drv   fl category
# count           234          234       234  234  234      234
# unique           15           38        10    3    5        7
# top           dodge  caravan 2wd  auto(l4)    f    r      suv
# freq             37           11        83  106  168       62

# %% [markdown]
# #범주형 데이터
#
#
# *   명목형
# *   순서형

# %%
mpg.fl.unique()
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg["fl"].unique() #위 코드와 동일함
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg.fl.value_counts() #r범주 p범주 ... 들의 값을 알려주는거임.
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_index() #데이터타입 "시리즈"라고 부름
# Out:
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_index(ascending=False)
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_values()#기본
# Out:
# c      1
# d      5
# e      8
# p     52
# r    168
# Name: fl, dtype: int64

# %%
mpg.fl.value_counts().sort_values(ascending=False)
# Out:
# r    168
# p     52
# e      8
# d      5
# c      1
# Name: fl, dtype: int64

# %%
mpg[["fl","category"]].value_counts() # r suv는 48 유니크한것의 갯수임.
# Out:
# fl  category
# r   suv           48
#     pickup        30
#     subcompact    29
#     midsize       26
#     compact       25
# p   compact       21
#     midsize       15
# r   minivan       10
# p   suv            8
#     2seater        5
# e   suv            4
# p   subcompact     3
# e   pickup         3
# d   suv            2
#     subcompact     2
#     compact        1
# e   minivan        1
# c   subcompact     1
# dtype: int64

# %%
mpg[["fl","category"]].value_counts().to_frame()
#데이터프레임
# Out:
#                 0
# fl category
# r  suv         48
#    pickup      30
#    subcompact  29
#    midsize     26
#    compact     25
# p  compact     21
#    midsize     15
# r  minivan     10
# p  suv          8
#    2seater      5
# e  suv          4
# p  subcompact   3
# e  pickup       3
# d  suv          2
#    subcompact   2
#    compact      1
# e  minivan      1
# c  subcompact   1

# %% [markdown]
# #함수와 메서드 차이 알아보기
#
# *  함수(내장함수)
# *  메소드
# *  패키지함수

# %% [markdown]
# ### 05-2 변수명 바꾸기(p.113):시험예상

# %%
df_raw = pd.DataFrame({"var1": [1,2,1],
                       "var2": [2,3,2],
                       "var3": [10,20,30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new = df_raw.copy()
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns = {'var2': 'v2'}) # var2를 v2로 바꾸겟다는거!바꾼 데이터프레임이 바로보인다.
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new # 반환만해주는거지 저장을 해주는건아님
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns = {'var2': 'v2'},inplace=True) #바로 반환가능
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(index = {0: "x", 1: "y", 2: "z"}, inplace=True)
df_new
# 0, 1, 2를 x, y, z로 바꾼거
# Out:
#    var1  var2  var3
# x     1     2    10
# y     2     3    20
# z     1     2    30

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
df.rename(columns={"A": "a", "B": "c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df_raw = pd.DataFrame({'var1' : [1, 2, 1],
                       'var2' : [2, 3, 2],
                       'var3' : [10, 20, 30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df1 = df.copy()
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df1 = df.copy()
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df['var_sum'] = df1['var1'] + df1['var2']
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'var1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1['var_mean'] = (df1["var1"] + df1['var2']) / 2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'var1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df2 = df.copy()
df2
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df2.sum() #열 별로
# Out:
# A     6
# B    15
# dtype: int64

# %%
df2.sum(axis=1) #axis는 열별로 (?)
# Out:
# 0    10
# 1    14
# 2    18
# dtype: int64

# %%
df2['my_sum'] = df2.sum(axis='columns')
df2
# Out:
#    A  B  my_sum
# 0  1  4      10
# 1  2  5      14
# 2  3  6      18

# %%
# 새로운 열 var_mean <- var1과 var2의 평균
df2["my_mean"] = df2[["var1","var2"]].mean(axis=1) # 시험 예상
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-d325bb5a1a30> in <cell line: 2>()
#       1 # 새로운 열 var_mean <- var1과 var2의 평균
# ----> 2 df2["my_mean"] = df2[["var1","var2"]].mean(axis=1) # 시험 예상
#       3 df2
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
# ...

# %% [markdown]
# #mpg 통합 연비 변수 만들기

# %%
#mpg 데이터 불러오기
mpg = pd.read_csv('data/mpg.csv')
mpg.sample(8)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 17          audi           a6 quattro    4.2  2008    8    auto(s6)   4   16
# 95          ford              mustang    4.6  1999    8  manual(m5)   r   15
# 171       subaru          impreza awd    2.5  2008    4  manual(m5)   4   19
# 225   volkswagen           new beetle    2.5  2008    5  manual(m5)   f   20
# 73         dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4   11
# 206       toyota    toyota tacoma 4wd    4.0  2008    6    auto(l5)   4   16
# 24     chevrolet             corvette    5.7  1999    8    auto(l4)   r   15
# 96          ford              mustang    4.6  2008    8  manual(m5)   r   15
#
#      hwy fl    category
# 17    23  p     midsize
# 95    22  r  subcompact
# 171   25  p     compact
# 225   28  r  subcompact
# 73    15  r      pickup
# 206   20  r      pickup
# 24    23  p     2seater
# 96    23  r  subcompact

# %%
#통합 연비 변수(total) 만들기, total <= cty + hwy의 평균: 시험에상
mpg['total'] = (mpg['cty'] + mpg['hwy']) /2 # 통합 연비 변수 만들기
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
#통합 연비 변수(mpg.mean)만들기, total <=- cty + hwy의 평균: 시험예상
mpg['mpg_mean'] = mpg[['cty', 'hwy']].mean(axis='columns') #통합 연비 변수 만들기
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
sum(mpg['total']) / len(mpg) #total 합계를 행 수로 나누기
# Out:
# 20.14957264957265

# %%
mpg['total'].mean() #통합 연비 변수 평균
# Out:
# 20.14957264957265

# %% [markdown]
# ###조건문을 활용해 파생변수 만들기(p.118)

# %%
mpg['total'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
#히스토그램, 도수분포표 만들기
mpg['total'].plot.hist();

# %%
mpg['total'].plot(kind="hist", title="히스토그램");

# %%
import seaborn as sns

sns.histplot(mpg, x="total"); #x=mpg.total

# %% [markdown]
# #2.합격 판정 변수 만들기 p.120

# %%
import numpy as np

#20 이상이면 pass, 그렇지 않으면 fail 부여
mpg['test'] = np.where(mpg['total'] >=20, 'pass', 'fail') #np.where가 조건문
mpg.sample(10)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 10          audi           a4 quattro    2.0  2008    4    auto(s6)   4   19
# 102        honda                civic    1.6  1999    4  manual(m5)   f   23
# 122         jeep   grand cherokee 4wd    3.0  2008    6    auto(l5)   4   17
# 220   volkswagen                jetta    2.8  1999    6  manual(m5)   f   17
# 55         dodge    dakota pickup 4wd    5.2  1999    8  manual(m5)   4   11
# 207   volkswagen                  gti    2.0  1999    4  manual(m5)   f   21
# 46         dodge          caravan 2wd    3.8  2008    6    auto(l6)   f   16
# 22     chevrolet   c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4   13
# 142       nissan               altima    2.4  1999    4    auto(l4)   f   19
#
#      hwy fl    category  total  mpg_mean  test
# 10    27  p     compact   23.0      23.0  pass
# ...

# %%
mpg['test'].value_counts() #연비 합격 빈도표 만들기
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
mpg['test'].unique()
# Out:
# array(['pass', 'fail'], dtype=object)

# %%
count_test = mpg['test'].value_counts()

# %%
type(count_test)
# Out:
# pandas.core.series.Series

# %%
count_test.plot.bar(); #연비 합격 빈도 막대 그래프 만들기

# %%
sns.countplot(mpg, x="test",hue=mpg.test); #mpg test

# %%
sns.countplot(data=mpg, x="test", hue="test", stat="percent"); #시험예상

# %%
sns.countplot(data=mpg, x="test", hue="cyl", stat="percent"); #시험예상
#실린더 cyl 순임. (엔진의 수)

# %%
sns.countplot(data=mpg, x="test", hue="category", stat="percent"); #시험예상

# %%
# total 기준으로 A, B, C 등급 부여
mpg['grade'] = np.where(mpg['total'] >= 30, 'A',
               np.where(mpg['total'] >= 20, 'B', 'C'))

#데이터 확인
mpg.sample(5)
# Out:
#     manufacturer               model  displ  year  cyl     trans drv  cty  \
# 222   volkswagen          new beetle    1.9  1999    4  auto(l4)   f   29
# 105        honda               civic    1.8  2008    4  auto(l5)   f   25
# 39         dodge         caravan 2wd    3.3  1999    6  auto(l4)   f   16
# 19     chevrolet  c1500 suburban 2wd    5.3  2008    8  auto(l4)   r   11
# 160       subaru        forester awd    2.5  1999    4  auto(l4)   4   18
#
#      hwy fl    category  total  mpg_mean  test grade
# 222   41  d  subcompact   35.0      35.0  pass     A
# 105   36  r  subcompact   30.5      30.5  pass     A
# 39    22  r     minivan   19.0      19.0  fail     C
# 19    15  e         suv   13.0      13.0  fail     C
# 160   24  r         suv   21.0      21.0  pass     B

# %%
count_grade = mpg['grade'].value_counts() #등급 빈도표 만들기
count_grade #숫자가 큰순서대로나옴
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot = 0) #등급 빈도 막대 그래프 만들기
# Out:
# <Axes: >

# %%
count_grade = mpg['grade'].value_counts().sort_index() #등급 빈도표 만들기
count_grade
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
#등급 빈도 막대 그래프 만들기
count_grade.plot.bar(rot=0)
# Out:
# <Axes: >

# %%
sns.countplot(mpg, x="grade", hue="grade");

# %%
sns.countplot(mpg, x="grade", hue="grade", stat='percent');

# %%
mpg['grade'].value_counts().sort_index().index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
sns.countplot(mpg, x="grade", hue="grade", order=np.sort(mpg['grade'].unique()))
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
mpg['grade'].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %% [markdown]
# #메소드 체이닝 (알아두면 좋아요 p.126)

# %%
#출력 결과를 변수에 할당하는 방법
s = mpg['grade']
s = s.value_counts()
s = s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
s # sort value는 숫자이고 sort index는 문자 A,B,C를 뜻함
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
s = mpg['grade'].value_counts().sort_index()
s
# .이 3~4개까지정도는 해석하는데 괜찮다.
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %% [markdown]
# #필요한 만큼 범주 만들기

# %%
#A, B, C, D등급 변수 만들기
mpg['grade2'] = np.where(mpg['total'] >=30, 'A',
                np.where(mpg['total'] >=25, 'B',
                np.where(mpg['total'] >=20, 'C', 'D')))
mpg.sample(4)
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 87          ford  f150 pickup 4wd    4.6  2008    8    auto(l4)   4   13   17
# 166       subaru      impreza awd    2.2  1999    4  manual(m5)   4   19   26
# 142       nissan           altima    2.4  1999    4    auto(l4)   f   19   27
# 190       toyota     camry solara    3.0  1999    6    auto(l4)   f   18   26
#
#     fl    category  total  mpg_mean  test grade grade2
# 87   r      pickup   15.0      15.0  fail     C      D
# 166  r  subcompact   22.5      22.5  pass     B      C
# 142  r     compact   23.0      23.0  pass     B      C
# 190  r     compact   22.0      22.0  pass     B      C

# %% [markdown]
# #연산자|(or),메소드 isin

# %%
mpg['size'] = np.where((mpg['category'] == 'compact') | (mpg['category'] == 'subcompact') | (mpg['category'] == '2seater'),
                       'small', 'large')

mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %%
mpg['size'] = np.where(mpg['category'].isin(['compact', 'subcompact', '2seater']), 'small', 'large')

mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %% [markdown]
# #정리하기

# %%
#1. 패키지 로드
import pandas as pd
import numpy as np

#2. 데이터 불러오기
mpg = pd.read_csv('data/mpg,csv')

#3. 데이터 파악하기
mpg.shape #행, 열 수
mpg.head() #데이터 앞부분
mpg.tail() #데이터 뒷부분
mpg.info() #속성
mpg.describe # 요약 통계량

# 4. 변수명 바꾸기
mpg = mpg.rename(columns = {'manufacturer': 'company'})

#5.파생변수 만들기
mpg['total'] = mpg['test'].value_counts() #빈도표 만들기
mpg['test'] = np.where(mpg['total'] >=20, 'pass', 'fail') #조건문 활용

#6.빈도 확인하기
count_test = mpg['test'].value_counts() #빈도표 만들기
count_test.plot.bar(rot=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-188-c84cfb14c24c> in <cell line: 6>()
#       4
#       5 #2. 데이터 불러오기
# ----> 6 mpg = pd.read_csv('data/mpg,csv')
#       7
#       8 #3. 데이터 파악하기
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
